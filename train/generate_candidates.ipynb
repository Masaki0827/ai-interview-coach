# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AI599/final/colab
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/AI599/final/colab
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 42.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.1/761.1 kB 59.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 53.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
# !python train/generate_candidates.py
# Out:
# Loading model: Qwen/Qwen2.5-3B-Instruct
# ...
# config.json: 100% 661/661 [00:00<00:00, 2.61MB/s]
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 10.4MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 43.6MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 109MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 136MB/s]
# model.safetensors.index.json: 100% 35.6k/35.6k [00:00<00:00, 88.9MB/s]
# ...
# Fetching 2 files: 100% 2/2 [00:17<00:00,  8.98s/it]
# Download complete: 100% 6.17G/6.17G [00:18<00:00, 342MB/s]
# Loading weights: 100% 434/434 [00:01<00:00, 270.83it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.61MB/s]
# [4/4653] Generating candidates for train_0004
# [5/4653] Generating candidates for train_0005
# [6/4653] Generating candidates for train_0006
# [7/4653] Generating candidates for train_0007
# [8/4653] Generating candidates for train_0008
# [9/4653] Generating candidates for train_0009
# ...
